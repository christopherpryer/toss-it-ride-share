# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import sklearn as sk
import scipy as sp

# %%
df = pd.read_csv('./data/litter_index_lines.csv')
df.head()
# Out:
#    objectid  seg_id  hundred_block_score        l_hundred_block  \
# 0        67  420542             1.333333  2000 SPRING GARDEN ST
# 1        68  420410             1.333333   2000 MOUNT VERNON ST
# 2        69  421797             1.333333          600 N 21ST ST
# 3        70  420415             1.333333           2100 CLAY ST
# 4        71  421798             1.333333          600 N 21ST ST
#
#         r_hundred_block  street_class street_class_name
# 0    0 SPRING GARDEN ST             2    Major Arterial
# 1  2000 MOUNT VERNON ST             5             Local
# 2         600 N 21ST ST             4         Collector
# 3          2100 CLAY ST             5             Local
# 4         600 N 21ST ST             4         Collector

# %%
df.shape
# Out:
# (39746, 7)

# %%
df.describe()
# Out:
#            objectid        seg_id  hundred_block_score  street_class
# count  39746.000000  3.974600e+04         39746.000000  39746.000000
# mean   19873.500000  5.820662e+05             1.736402      4.093670
# std    11473.826236  2.203415e+05             0.707395      1.004484
# min        1.000000  1.000010e+05             0.000000      2.000000
# 25%     9937.250000  4.137562e+05             1.333333      4.000000
# 50%    19873.500000  5.427955e+05             1.666667      4.000000
# 75%    29809.750000  7.413240e+05             2.000000      5.000000
# max    39746.000000  1.180105e+06             4.000000     18.000000

# %%
df[['hundred_block_score', 'street_class_name']].hist(by='street_class_name')
# Out:
# <img src="data:image/png;base64,..." width="844.5454362404251">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2B7CC8C88>,
# ...
#       dtype=object)

# %%
df.sort_values('hundred_block_score', ascending=False).head()
# Out:
#        objectid  seg_id  hundred_block_score      l_hundred_block  \
# 13596     14643  540290                  4.0  700 E CLEARFIELD ST
# 28005     25996  620600                  4.0       4500 N 18TH ST
# 4391       6060  520681                  4.0   1900 W INDIANA AVE
# 7314       5795  521242                  4.0       1400 N 21ST ST
# 39304     38578  322821                  4.0    1200 S HARMONY ST
#
#            r_hundred_block  street_class street_class_name
# 13596  700 E CLEARFIELD ST             4         Collector
# 28005       4500 N 18TH ST             4         Collector
# 4391    1900 W INDIANA AVE             4         Collector
# 7314        1400 N 21ST ST             4         Collector
# 39304    1200 S HARMONY ST             5             Local

# %%
df.sort_values('hundred_block_score', ascending=False).tail()
# Out:
#        objectid  seg_id  hundred_block_score  l_hundred_block  \
# 4963       7177  741205                  0.0     0 MASCHER ST
# 30994     30368  740935                  0.0      0 BRIDGE ST
# 30995     30369  740943                  0.0      0 BRIDGE ST
# 34230     35230  880667                  0.0  8800 JACKSON ST
# 33959     35147  323603                  0.0   5300 GIBSON DR
#
#        r_hundred_block  street_class street_class_name
# 4963      0 MASCHER ST             3    Minor Arterial
# 30994      0 BRIDGE ST             4         Collector
# 30995      0 BRIDGE ST             4         Collector
# 34230  8800 JACKSON ST             5             Local
# 33959   5300 GIBSON DR             5             Local
